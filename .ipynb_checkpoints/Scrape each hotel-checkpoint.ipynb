# %%
from bs4 import BeautifulSoup

# %%
from selenium import webdriver
from selenium.webdriver.firefox.options import Options

def create_firefox_webdriver(headless=False):
    # Set options for WebDriver
    options = Options()
    options.headless = headless

    # Create a new instance of the Firefox driver
    driver = webdriver.Firefox(options=options)

    return driver

driver = create_firefox_webdriver(headless=True)

# %%
##Load hotel list
import pandas as pd
hotels = pd.read_excel('Hotels in Ayodhya.xlsx')

# %%
import time
for i, row in hotels.iterrows():
    link = row['link']
    driver.get('https://'+link)
    time.sleep(2)
    soup = BeautifulSoup(driver.page_source)
    
    
    # Directory to save the images
    directory = 'hotel_images/' + row['Hotel_Name']

    break

# %%
soup
# Out:
# <html dir="ltr" lang="eng" style="--font-scale: 1;"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=5" name="viewport"/>
# <meta content="#FFF" name="theme-color"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//fonts.gstatic.com" rel="dns-prefetch"/>
# <link href="//imgak.mmtcdn.com" rel="dns-prefetch"/>
# <link href="//jsak.mmtcdn.com" rel="dns-prefetch"/>
# <link href="//imgak.mmtcdn.com" rel="preconnect"/>
# <link href="//jsak.mmtcdn.com" rel="preconnect"/>
# ...

# %%
## Mine this soup object for all available information you can find about the each hotel
